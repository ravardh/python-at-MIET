# %%
import numpy as np
import pandas as pd

# %%
dic= {
    "Name":["Ram","Shyam","Sameer","Kajal","Irfan","Rohit"],
    "Roll no":[1,2,3,4,5,6],
    "Grades":["A","B","C","C","B","A"],
    "Email":["abc@xyz.com","def@xyz.com","ghi@xyz.com","jkl@xyz.com","mno@xyz.com","qrs@xyz.com"]
}

# %%
dic
# Out:
# {'Name': ['Ram', 'Shyam', 'Sameer', 'Kajal', 'Irfan', 'Rohit'],
#  'Roll no': [1, 2, 3, 4, 5, 6],
#  'Grades': ['A', 'B', 'C', 'C', 'B', 'A'],
#  'Email': ['abc@xyz.com',
#   'def@xyz.com',
#   'ghi@xyz.com',
#   'jkl@xyz.com',
#   'mno@xyz.com',
#   'qrs@xyz.com']}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      C  jkl@xyz.com
# 4   Irfan        5      B  mno@xyz.com
# 5   Rohit        6      A  qrs@xyz.com

# %%
df.head()
# Out:
#      Name  Roll no Grades        Email
# 0     Ram        1      A  abc@xyz.com
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      C  jkl@xyz.com
# 4   Irfan        5      B  mno@xyz.com

# %%
df.tail()
# Out:
#      Name  Roll no Grades        Email
# 1   Shyam        2      B  def@xyz.com
# 2  Sameer        3      C  ghi@xyz.com
# 3   Kajal        4      C  jkl@xyz.com
# 4   Irfan        5      B  mno@xyz.com
# 5   Rohit        6      A  qrs@xyz.com

# %%
df.head(2)
# Out:
#     Name  Roll no Grades        Email
# 0    Ram        1      A  abc@xyz.com
# 1  Shyam        2      B  def@xyz.com

# %%
df.tail(2)
# Out:
#     Name  Roll no Grades        Email
# 4  Irfan        5      B  mno@xyz.com
# 5  Rohit        6      A  qrs@xyz.com

# %%
df.describe()
# Out:
#         Roll no
# count  6.000000
# mean   3.500000
# std    1.870829
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    6.000000

# %%
cus = pd.read_csv('Customer.csv')

# %%
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
type(cus)
# Out:
# pandas.core.frame.DataFrame

# %%
type(cus['CustomerID'])
# Out:
# pandas.core.series.Series

# %%
cus.index
# Out:
# RangeIndex(start=0, stop=91, step=1)

# %%
cus.columns
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy()
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.T
# Out:
#                                 0                                   1   \
# CustomerID                       1                                   2
# Company Name   Alfreds Futterkiste  Ana Trujillo Emparedados y helados
# Costumer Name         Maria Anders                        Ana Trujillo
# City                        Berlin                         Mexico D.F.
# PostalCode                   12209                                5021
# Country                    Germany                              Mexico
#
#                                     2                3                   4   \
# CustomerID                           3                4                   5
# Company Name   Antonio Moreno Taqueria  Around the Horn   Berglunds snabbkp
# Costumer Name           Antonio Moreno     Thomas Hardy  Christina Berglund
# City                       Mexico D.F.           London               Lulea
# PostalCode                        5023            34626               95822
# ...

# %%
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.drop('Company Name',axis=1)
# Out:
#     CustomerID       Costumer Name         City  PostalCode  Country
# 0            1        Maria Anders       Berlin       12209  Germany
# 1            2        Ana Trujillo  Mexico D.F.        5021   Mexico
# 2            3      Antonio Moreno  Mexico D.F.        5023   Mexico
# 3            4        Thomas Hardy       London       34626       UK
# 4            5  Christina Berglund        Lulea       95822   Sweden
# ..         ...                 ...          ...         ...      ...
# 86          87    Pirkko Koskitalo         Oulu       90110  Finland
# 87          88       Paula Parente      Resende       51849   Brazil
# 88          89      Karl Jablonski      Seattle       98128      USA
# 89          90     Matti Karttunen     Helsinki       21240  Finland
# 90          91             Zbyszek        Walla       56189   Poland
#
# [91 rows x 5 columns]

# %%
cus.loc[(48,78),('Company Name','Costumer Name')]
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 78            Toms Spezialitaten     Karin Josephs

# %%
cus.loc[tuple((np.arange(48,78))),('Company Name','Costumer Name')]
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
cus.loc[np.arange(48,78),('Company Name','Costumer Name')]
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
cus.loc[np.arange(48,78),:]
# Out:
#     CustomerID                  Company Name        Costumer Name  \
# 48          49  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49          50                  Maison Dewey      Catherine Dewey
# 50          51                Mere Paillarde       Jean Fresniere
# 51          52        Morgenstern Gesundkost      Alexander Feuer
# 52          53                   North/South       Simon Crowther
# 53          54        Oceano Atlantico Ltda.       Yvonne Moncada
# 54          55        Old World Delicatessen        Rene Phillips
# 55          56            Ottilies Kaseladen  Henriette Pfalzheim
# 56          57             Paris specialites       Marie Bertrand
# 57          58     Pericles Comidas clasicas  Guillermo Fernandez
# 58          59              Piccolo und mehr          Georg Pipps
# 59          60       Princesa Isabel Vinhoss     Isabel de Castro
# 60          61                   Que Delicia     Bernardo Batista
# ...

# %%
cus.loc[:,'Company Name']
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
np.array(cus.loc[:,'Company Name'])
# Out:
# array(['Alfreds Futterkiste', 'Ana Trujillo Emparedados y helados',
#        'Antonio Moreno Taqueria', 'Around the Horn', 'Berglunds snabbkp',
#        'Blauer See Delikatessen', 'Blondel pere et fils',
#        'BOlido Comidas preparadas', 'Bon app', 'Bottom-Dollar Marketse',
#        'Bs Beverages', 'Cactus Comidas para llevar',
#        'Centro comercial Moctezuma', 'Chop-suey Chinese',
#        'Comercio Mineiro', 'Consolidated Holdings',
#        'Drachenblut Delikatessend', 'Du monde entier',
#        'Eastern Connection', 'Ernst Handel', 'Familia Arquibaldo',
#        'FISSA Fabrica Inter. Salchichas S.A.', 'Folies gourmandes',
#        'Folk och fa HB', 'Frankenversand', 'France restauration',
#        'Franchi S.p.A.', 'Furia Bacalhau e Frutos do Mar',
#        'Galeria del gastrOnomo', 'Godos Cocina Tipica',
#        'Gourmet Lanchonetes', 'Great Lakes Food Market',
#        'GROSELLA-Restaurante', 'Hanari Carnes', 'HILARION-Abastos',
# ...

# %%
CN=cus.loc[:,'Company Name']
CN
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
company_data = {
    1: {"company_name": "Tech Innovators", "employee_name": "Alice Johnson", "position": "Software Engineer"},
    2: {"company_name": "Creative Solutions", "employee_name": "Bob Smith", "position": "Graphic Designer"},
    3: {"company_name": "Market Gurus", "employee_name": "Carol White", "position": "Marketing Manager"},
    4: {"company_name": "Finance Experts", "employee_name": "David Brown", "position": "Financial Analyst"},
    5: {"company_name": "HealthFirst", "employee_name": "Eve Davis", "position": "Healthcare Administrator"},
    6: {"company_name": "EduTech", "employee_name": "Frank Miller", "position": "Curriculum Developer"},
    7: {"company_name": "Retail Giants", "employee_name": "Grace Wilson", "position": "Store Manager"},
    8: {"company_name": "AutoMobility", "employee_name": "Henry Taylor", "position": "Mechanical Engineer"},
    9: {"company_name": "Green Energy", "employee_name": "Ivy Moore", "position": "Environmental Scientist"},
    10: {"company_name": "Foodies Inc.", "employee_name": "Jack Anderson", "position": "Chef"},
    11: {"company_name": "Media House", "employee_name": "Kate Thompson", "position": "Journalist"},
    12: {"company_name": "Travel Experts", "employee_name": "Leo Walker", "position": "Travel Agent"},
    13: {"company_name": "Logistics Pro", "employee_name": "Mia Harris", "position": "Logistics Coordinator"},
    14: {"company_name": "Tech Innovators", "employee_name": "Nathan Clark", "position": "Data Scientist"},
    15: {"company_name": "Creative Solutions", "employee_name": "Olivia Lewis", "position": "UX Designer"},
    16: {"company_name": "Market Gurus", "employee_name": "Paul Robinson", "position": "SEO Specialist"},
    17: {"company_name": "Finance Experts", "employee_name": "Quinn Hall", "position": "Accountant"},
    18: {"company_name": "HealthFirst", "employee_name": "Rachel Young", "position": "Nurse"},
    19: {"company_name": "EduTech", "employee_name": "Sam King", "position": "E-Learning Specialist"},
    20: {"company_name": "Retail Giants", "employee_name": "Tina Scott", "position": "Sales Associate"},
    21: {"company_name": "AutoMobility", "employee_name": "Umar Green", "position": "Automotive Technician"},
    22: {"company_name": "Green Energy", "employee_name": "Vera Adams", "position": "Renewable Energy Engineer"},
    23: {"company_name": "Foodies Inc.", "employee_name": "Will Baker", "position": "Pastry Chef"},
    24: {"company_name": "Media House", "employee_name": "Xena Martin", "position": "Photographer"},
    25: {"company_name": "Travel Experts", "employee_name": "Yara Perez", "position": "Tour Guide"},
    26: {"company_name": "Logistics Pro", "employee_name": "Zane Campbell", "position": "Warehouse Manager"},
    27: {"company_name": "Tech Innovators", "employee_name": "Aaron Lee", "position": "IT Support Specialist"},
    28: {"company_name": "Creative Solutions", "employee_name": "Bella Young", "position": "Content Writer"},
    29: {"company_name": "Market Gurus", "employee_name": "Chris Nelson", "position": "Market Research Analyst"},
    30: {"company_name": "Finance Experts", "employee_name": "Dana Parker", "position": "Investment Advisor"},
    31: {"company_name": "HealthFirst", "employee_name": "Eli Reed", "position": "Medical Assistant"},
    32: {"company_name": "EduTech", "employee_name": "Fiona Turner", "position": "Instructional Designer"},
    33: {"company_name": "Retail Giants", "employee_name": "George Hughes", "position": "Customer Service Representative"},
    34: {"company_name": "AutoMobility", "employee_name": "Hannah Long", "position": "Automotive Engineer"},
    35: {"company_name": "Green Energy", "employee_name": "Ian Rogers", "position": "Sustainability Consultant"},
    36: {"company_name": "Foodies Inc.", "employee_name": "Jane Sanders", "position": "Restaurant Manager"},
    37: {"company_name": "Media House", "employee_name": "Kyle Fisher", "position": "Editor"},
    38: {"company_name": "Travel Experts", "employee_name": "Luna Griffin", "position": "Travel Consultant"},
    39: {"company_name": "Logistics Pro", "employee_name": "Mike Collins", "position": "Supply Chain Analyst"},
    40: {"company_name": "Tech Innovators", "employee_name": "Nina Powell", "position": "Systems Administrator"},
    41: {"company_name": "Creative Solutions", "employee_name": "Omar Price", "position": "Art Director"},
    42: {"company_name": "Market Gurus", "employee_name": "Paula Richardson", "position": "Digital Marketing Specialist"},
    43: {"company_name": "Finance Experts", "employee_name": "Quincy Ward", "position": "Credit Analyst"},
    44: {"company_name": "HealthFirst", "employee_name": "Rose Barnes", "position": "Physician Assistant"},
    45: {"company_name": "EduTech", "employee_name": "Steve Morgan", "position": "Educational Consultant"},
    46: {"company_name": "Retail Giants", "employee_name": "Tara Murphy", "position": "Merchandise Planner"},
    47: {"company_name": "AutoMobility", "employee_name": "Ulysses Fox", "position": "Vehicle Inspector"},
    48: {"company_name": "Green Energy", "employee_name": "Valerie Cooper", "position": "Energy Consultant"},
    49: {"company_name": "Foodies Inc.", "employee_name": "Wendy Simmons", "position": "Sous Chef"},
    50: {"company_name": "Media House", "employee_name": "Xander Lee", "position": "Broadcast Technician"}
}

print(company_data)
# Out:
# {1: {'company_name': 'Tech Innovators', 'employee_name': 'Alice Johnson', 'position': 'Software Engineer'}, 2: {'company_name': 'Creative Solutions', 'employee_name': 'Bob Smith', 'position': 'Graphic Designer'}, 3: {'company_name': 'Market Gurus', 'employee_name': 'Carol White', 'position': 'Marketing Manager'}, 4: {'company_name': 'Finance Experts', 'employee_name': 'David Brown', 'position': 'Financial Analyst'}, 5: {'company_name': 'HealthFirst', 'employee_name': 'Eve Davis', 'position': 'Healthcare Administrator'}, 6: {'company_name': 'EduTech', 'employee_name': 'Frank Miller', 'position': 'Curriculum Developer'}, 7: {'company_name': 'Retail Giants', 'employee_name': 'Grace Wilson', 'position': 'Store Manager'}, 8: {'company_name': 'AutoMobility', 'employee_name': 'Henry Taylor', 'position': 'Mechanical Engineer'}, 9: {'company_name': 'Green Energy', 'employee_name': 'Ivy Moore', 'position': 'Environmental Scientist'}, 10: {'company_name': 'Foodies Inc.', 'employee_name': 'Jack 
# ...

# %%
cd=pd.DataFrame(company_data)
cd
# Out:
#                               1                   2                  3   \
# company_name     Tech Innovators  Creative Solutions       Market Gurus
# employee_name      Alice Johnson           Bob Smith        Carol White
# position       Software Engineer    Graphic Designer  Marketing Manager
#
#                               4                         5   \
# company_name     Finance Experts               HealthFirst
# employee_name        David Brown                 Eve Davis
# position       Financial Analyst  Healthcare Administrator
#
#                                  6              7                    8   \
# company_name                EduTech  Retail Giants         AutoMobility
# employee_name          Frank Miller   Grace Wilson         Henry Taylor
# position       Curriculum Developer  Store Manager  Mechanical Engineer
#
#                                     9              10  ...  \
# company_name              Green Energy   Foodies Inc.  ...
# ...

# %%
cd=cd.T

# %%
cd
# Out:
#           company_name     employee_name                         position
# 1      Tech Innovators     Alice Johnson                Software Engineer
# 2   Creative Solutions         Bob Smith                 Graphic Designer
# 3         Market Gurus       Carol White                Marketing Manager
# 4      Finance Experts       David Brown                Financial Analyst
# 5          HealthFirst         Eve Davis         Healthcare Administrator
# 6              EduTech      Frank Miller             Curriculum Developer
# 7        Retail Giants      Grace Wilson                    Store Manager
# 8         AutoMobility      Henry Taylor              Mechanical Engineer
# 9         Green Energy         Ivy Moore          Environmental Scientist
# 10        Foodies Inc.     Jack Anderson                             Chef
# 11         Media House     Kate Thompson                       Journalist
# 12      Travel Experts        Leo Walker                     Travel Agent
# ...

# %%
cd.drop_duplicates(subset='company_name',keep=False)
# Out:
# Empty DataFrame
# Columns: [company_name, employee_name, position]
# Index: []

# %%
cd
# Out:
#           company_name     employee_name                         position
# 1      Tech Innovators     Alice Johnson                Software Engineer
# 2   Creative Solutions         Bob Smith                 Graphic Designer
# 3         Market Gurus       Carol White                Marketing Manager
# 4      Finance Experts       David Brown                Financial Analyst
# 5          HealthFirst         Eve Davis         Healthcare Administrator
# 6              EduTech      Frank Miller             Curriculum Developer
# 7        Retail Giants      Grace Wilson                    Store Manager
# 8         AutoMobility      Henry Taylor              Mechanical Engineer
# 9         Green Energy         Ivy Moore          Environmental Scientist
# 10        Foodies Inc.     Jack Anderson                             Chef
# 11         Media House     Kate Thompson                       Journalist
# 12      Travel Experts        Leo Walker                     Travel Agent
# ...

# %%
cd.to_csv('company data.csv',index=False)

# %% [markdown]
# # xlrd and openpyxl are the libraries to handel excel files in pandas

# %%
com_dat=pd.read_csv('company data.csv')
com_dat
# Out:
#           company_name     employee_name                         position
# 0      Tech Innovators     Alice Johnson                Software Engineer
# 1   Creative Solutions         Bob Smith                 Graphic Designer
# 2         Market Gurus       Carol White                Marketing Manager
# 3      Finance Experts       David Brown                Financial Analyst
# 4          HealthFirst         Eve Davis         Healthcare Administrator
# 5              EduTech      Frank Miller             Curriculum Developer
# 6        Retail Giants      Grace Wilson                    Store Manager
# 7         AutoMobility      Henry Taylor              Mechanical Engineer
# 8         Green Energy         Ivy Moore          Environmental Scientist
# 9         Foodies Inc.     Jack Anderson                             Chef
# 10         Media House     Kate Thompson                       Journalist
# 11      Travel Experts        Leo Walker                     Travel Agent
# ...

# %%
com_dat.drop(2,axis=0)
# Out:
#           company_name     employee_name                         position
# 0      Tech Innovators     Alice Johnson                Software Engineer
# 1   Creative Solutions         Bob Smith                 Graphic Designer
# 3      Finance Experts       David Brown                Financial Analyst
# 4          HealthFirst         Eve Davis         Healthcare Administrator
# 5              EduTech      Frank Miller             Curriculum Developer
# 6        Retail Giants      Grace Wilson                    Store Manager
# 7         AutoMobility      Henry Taylor              Mechanical Engineer
# 8         Green Energy         Ivy Moore          Environmental Scientist
# 9         Foodies Inc.     Jack Anderson                             Chef
# 10         Media House     Kate Thompson                       Journalist
# 11      Travel Experts        Leo Walker                     Travel Agent
# 12       Logistics Pro        Mia Harris            Logistics Coordinator
# ...

# %%
com_dat
# Out:
#           company_name     employee_name                         position
# 0      Tech Innovators     Alice Johnson                Software Engineer
# 1   Creative Solutions         Bob Smith                 Graphic Designer
# 2         Market Gurus       Carol White                Marketing Manager
# 3      Finance Experts       David Brown                Financial Analyst
# 4          HealthFirst         Eve Davis         Healthcare Administrator
# 5              EduTech      Frank Miller             Curriculum Developer
# 6        Retail Giants      Grace Wilson                    Store Manager
# 7         AutoMobility      Henry Taylor              Mechanical Engineer
# 8         Green Energy         Ivy Moore          Environmental Scientist
# 9         Foodies Inc.     Jack Anderson                             Chef
# 10         Media House     Kate Thompson                       Journalist
# 11      Travel Experts        Leo Walker                     Travel Agent
# ...

# %%
com_dat.drop(2,axis=0,inplace=True)

# %%
com_dat
# Out:
#           company_name     employee_name                         position
# 0      Tech Innovators     Alice Johnson                Software Engineer
# 1   Creative Solutions         Bob Smith                 Graphic Designer
# 3      Finance Experts       David Brown                Financial Analyst
# 4          HealthFirst         Eve Davis         Healthcare Administrator
# 5              EduTech      Frank Miller             Curriculum Developer
# 6        Retail Giants      Grace Wilson                    Store Manager
# 7         AutoMobility      Henry Taylor              Mechanical Engineer
# 8         Green Energy         Ivy Moore          Environmental Scientist
# 9         Foodies Inc.     Jack Anderson                             Chef
# 10         Media House     Kate Thompson                       Journalist
# 11      Travel Experts        Leo Walker                     Travel Agent
# 12       Logistics Pro        Mia Harris            Logistics Coordinator
# ...

# %%
com_dat.drop((i for i in [42,34,5,7]),axis=0,inplace=True)

# %%
com_dat
# Out:
#           company_name     employee_name                         position
# 0      Tech Innovators     Alice Johnson                Software Engineer
# 1   Creative Solutions         Bob Smith                 Graphic Designer
# 3      Finance Experts       David Brown                Financial Analyst
# 4          HealthFirst         Eve Davis         Healthcare Administrator
# 6        Retail Giants      Grace Wilson                    Store Manager
# 8         Green Energy         Ivy Moore          Environmental Scientist
# 9         Foodies Inc.     Jack Anderson                             Chef
# 10         Media House     Kate Thompson                       Journalist
# 11      Travel Experts        Leo Walker                     Travel Agent
# 12       Logistics Pro        Mia Harris            Logistics Coordinator
# 13     Tech Innovators      Nathan Clark                   Data Scientist
# 14  Creative Solutions      Olivia Lewis                      UX Designer
# ...

# %%
com_dat.reset_index(drop=True,inplace=True)

# %%
com_dat
# Out:
#           company_name     employee_name                         position
# 0      Tech Innovators     Alice Johnson                Software Engineer
# 1   Creative Solutions         Bob Smith                 Graphic Designer
# 2      Finance Experts       David Brown                Financial Analyst
# 3          HealthFirst         Eve Davis         Healthcare Administrator
# 4        Retail Giants      Grace Wilson                    Store Manager
# 5         Green Energy         Ivy Moore          Environmental Scientist
# 6         Foodies Inc.     Jack Anderson                             Chef
# 7          Media House     Kate Thompson                       Journalist
# 8       Travel Experts        Leo Walker                     Travel Agent
# 9        Logistics Pro        Mia Harris            Logistics Coordinator
# 10     Tech Innovators      Nathan Clark                   Data Scientist
# 11  Creative Solutions      Olivia Lewis                      UX Designer
# ...

# %%
com_dat.to_csv('company data.csv',index=False)

# %%
com_dat.to_excel('company data.xlsx',index=False)
